# %%
#!/usr/bin/env python3
"""
part2.py

UNSW COMP9444 Neural Networks and Deep Learning

ONLY COMPLETE METHODS AND CLASSES MARKED "TODO".

DO NOT MODIFY IMPORTS. DO NOT ADD EXTRA FUNCTIONS.
DO NOT MODIFY EXISTING FUNCTION SIGNATURES.
DO NOT IMPORT ADDITIONAL LIBRARIES.
DOING SO MAY CAUSE YOUR CODE TO FAIL AUTOMATED TESTING.
"""
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt


class LinearModel:
    def __init__(self, num_inputs, learning_rate):
        """
        Model is very similar to the Perceptron shown in Lectures 1c, slide 12, except that:
        (1) the bias is indexed by w(n+1) rather than w(0), and
        (2) the activation function is a (continuous) sigmoid rather than a (discrete) step function.

        x1 ----> * w1 ----\
        x2 ----> * w2 -----\
        x3 ----> * w3 ------\
        ...
                             \
        xn ----> * wn -------+--> s --> activation ---> z
        1  ----> * w(n+1) --/
        """
        self.num_inputs = num_inputs
        self.lr = learning_rate
        self.weights = np.asarray([1.0, -1.0, 0.0])  # Initialize as straight line

    def activation(self, x):
        """
        TODO: Implement a sigmoid activation function that accepts a float and returns
        a float, but raises a Value error if a boolean, list or numpy array is passed in
        hint: consider np.exp()
        """
        a = 1/(1 + np.exp(-x))
        return a

    def forward(self, inputs):
        """
        TODO: Implement the forward pass (inference) of a the model.

        inputs is a numpy array. The bias term is the last element in self.weights.
        hint: call the activation function you have implemented above.
        """
        Z = self.activation((np.dot(self.weights[1:].T,inputs) + self.weights[1]))
        return Z

    @staticmethod
    def loss(prediction, label):
        """
        TODO: Return the cross entropy for the given prediction and label
        hint: consider using np.log()
        """
#         m = label.shape[0]
#         print(prediction, label)
#         print("--------")
        Loss = -label*np.log(prediction) + (1-label) *np.log(1-prediction)
        return Loss

    @staticmethod
    def error(prediction, label):
        """
        TODO: Return the difference between the label and the prediction

        For example, if label= 1 and the prediction was 0.8, return 0.2
                     if label= 0 and the preduction was 0.43 return -0.43
        """
        return label - prediction

    def backward(self, inputs, diff):
        """
        TODO: Adjust self.weights by gradient descent

        We take advantage of the simplification shown in Lecture 2b, slide 23,
        to compute the gradient directly from the differential or difference
        dE/ds = z - t (which is passed in as diff)

        The resulting weight update should look essentially the same as for the
        Perceptron Learning Rule (shown in Lectures 1c, slide 11) except that
        the error can take on any continuous value between -1 and +1,
        rather than being restricted to the integer values -1, 0 or +1.

        Note: Numpy arrays are passed by reference and can be modified in-place
        """
        dW = inputs * diff
        db = diff

        self.weights[-1] += self.lr * db; # update bias
        self.weights[:2] += self.lr * dW; # update weights
        
        
    def plot(self, inputs, marker):
        """
        Plot the data and the decision boundary
        """
        xmin = inputs[:, 0].min() * 1.1
        xmax = inputs[:, 0].max() * 1.1
        ymin = inputs[:, 1].min() * 1.1
        ymax = inputs[:, 1].max() * 1.1

        x = np.arange(xmin * 1.3, xmax * 1.3, 0.1)
        plt.scatter(inputs[:25, 0], inputs[:25, 1], c="C0", edgecolors='w', s=100)
        plt.scatter(inputs[25:, 0], inputs[25:, 1], c="C1", edgecolors='w', s=100)

        plt.xlim((xmin, xmax))
        plt.ylim((ymin, ymax))
        plt.plot(x, -(self.weights[0] * x + self.weights[2]) / self.weights[1], marker, alpha=0.6)
        plt.title("Data and decision boundary")
        plt.xlabel("x1")
        plt.ylabel("x2").set_rotation(0)


def main():
    inputs, labels = pkl.load(open("../data/binary_classification_data.pkl", "rb"))

    epochs = 400
    model = LinearModel(num_inputs=inputs.shape[1], learning_rate=0.01)

    for i in range(epochs):
        num_correct = 0
        for x, y in zip(inputs, labels):
            # Get prediction

            output = model.forward(x)
            
            # Calculate loss
            cost = model.loss(output, y)

#             # Calculate difference or differential
            diff = model.error(output, y)

#             # Update the weights
            model.backward(x, diff)

#             # Record accuracy
            preds = output > 0.5  # 0.5 is midline of sigmoid
            num_correct += int(preds == y)
            

        print(f" Cost: {cost:8.6f} Accuracy: {num_correct / len(inputs) * 100}%")
        model.plot(inputs, "C2--")
    model.plot(inputs, "k")
    plt.show()

# %%
main()
# Out:
#  Cost: -0.302099 Accuracy: 50.0%
#  Cost: -0.337014 Accuracy: 50.0%
#  Cost: -0.372828 Accuracy: 50.0%
#  Cost: -0.409249 Accuracy: 50.0%
#  Cost: -0.446025 Accuracy: 50.0%
#  Cost: -0.482959 Accuracy: 50.0%
#  Cost: -0.519903 Accuracy: 48.0%
#  Cost: -0.556759 Accuracy: 48.0%
#  Cost: -0.593473 Accuracy: 48.0%
#  Cost: -0.630027 Accuracy: 48.0%
#  Cost: -0.666431 Accuracy: 48.0%
#  Cost: -0.702715 Accuracy: 46.0%
#  Cost: -0.738925 Accuracy: 46.0%
#  Cost: -0.775117 Accuracy: 46.0%
#  Cost: -0.811350 Accuracy: 44.0%
#  Cost: -0.847686 Accuracy: 44.0%
#  Cost: -0.884187 Accuracy: 44.0%
#  Cost: -0.920910 Accuracy: 44.0%
#  Cost: -0.957909 Accuracy: 42.0%
#  Cost: -0.995235 Accuracy: 42.0%
#  Cost: -1.032931 Accuracy: 42.0%
#  Cost: -1.071036 Accuracy: 44.0%
#  Cost: -1.109583 Accuracy: 44.0%
#  Cost: -1.148602 Accuracy: 44.0%
#  Cost: -1.188114 Accuracy: 44.0%
#  Cost: -1.228139 Accuracy: 42.0%
#  Cost: -1.268689 Accuracy: 42.0%
#  Cost: -1.309775 Accuracy: 42.0%
#  Cost: -1.351403 Accuracy: 42.0%
#  Cost: -1.393575 Accuracy: 42.0%
#  Cost: -1.436292 Accuracy: 42.0%
#  Cost: -1.479549 Accuracy: 42.0%
#  Cost: -1.523342 Accuracy: 42.0%
#  Cost: -1.567664 Accuracy: 42.0%
#  Cost: -1.612505 Accuracy: 42.0%
#  Cost: -1.657855 Accuracy: 42.0%
#  Cost: -1.703701 Accuracy: 42.0%
#  Cost: -1.750032 Accuracy: 40.0%
#  Cost: -1.796834 Accuracy: 40.0%
#  Cost: -1.844092 Accuracy: 40.0%
#  Cost: -1.891791 Accuracy: 40.0%
#  Cost: -1.939917 Accuracy: 40.0%
#  Cost: -1.988455 Accuracy: 40.0%
#  Cost: -2.037388 Accuracy: 40.0%
#  Cost: -2.086702 Accuracy: 40.0%
#  Cost: -2.136381 Accuracy: 40.0%
#  Cost: -2.186411 Accuracy: 40.0%
#  Cost: -2.236777 Accuracy: 40.0%
#  Cost: -2.287464 Accuracy: 40.0%
#  Cost: -2.338458 Accuracy: 38.0%
#  Cost: -2.389744 Accuracy: 38.0%
#  Cost: -2.441311 Accuracy: 38.0%
#  Cost: -2.493144 Accuracy: 38.0%
#  Cost: -2.545232 Accuracy: 38.0%
#  Cost: -2.597561 Accuracy: 38.0%
#  Cost: -2.650121 Accuracy: 38.0%
#  Cost: -2.702899 Accuracy: 38.0%
#  Cost: -2.755885 Accuracy: 38.0%
#  Cost: -2.809070 Accuracy: 38.0%
#  Cost: -2.862442 Accuracy: 38.0%
#  Cost: -2.915992 Accuracy: 38.0%
#  Cost: -2.969711 Accuracy: 38.0%
#  Cost: -3.023591 Accuracy: 38.0%
#  Cost: -3.077623 Accuracy: 38.0%
#  Cost: -3.131799 Accuracy: 38.0%
#  Cost: -3.186112 Accuracy: 38.0%
#  Cost: -3.240555 Accuracy: 38.0%
#  Cost: -3.295120 Accuracy: 38.0%
#  Cost: -3.349801 Accuracy: 38.0%
#  Cost: -3.404593 Accuracy: 38.0%
#  Cost: -3.459489 Accuracy: 38.0%
#  Cost: -3.514484 Accuracy: 38.0%
#  Cost: -3.569572 Accuracy: 38.0%
#  Cost: -3.624748 Accuracy: 38.0%
#  Cost: -3.680009 Accuracy: 38.0%
#  Cost: -3.735349 Accuracy: 38.0%
#  Cost: -3.790763 Accuracy: 38.0%
#  Cost: -3.846249 Accuracy: 38.0%
#  Cost: -3.901802 Accuracy: 38.0%
#  Cost: -3.957418 Accuracy: 38.0%
#  Cost: -4.013095 Accuracy: 38.0%
#  Cost: -4.068829 Accuracy: 38.0%
#  Cost: -4.124616 Accuracy: 38.0%
#  Cost: -4.180455 Accuracy: 38.0%
#  Cost: -4.236342 Accuracy: 38.0%
#  Cost: -4.292275 Accuracy: 38.0%
#  Cost: -4.348251 Accuracy: 38.0%
#  Cost: -4.404267 Accuracy: 38.0%
#  Cost: -4.460323 Accuracy: 38.0%
#  Cost: -4.516415 Accuracy: 38.0%
#  Cost: -4.572543 Accuracy: 38.0%
#  Cost: -4.628703 Accuracy: 38.0%
#  Cost: -4.684894 Accuracy: 38.0%
#  Cost: -4.741115 Accuracy: 38.0%
#  Cost: -4.797364 Accuracy: 38.0%
#  Cost: -4.853639 Accuracy: 38.0%
#  Cost: -4.909939 Accuracy: 38.0%
#  Cost: -4.966264 Accuracy: 38.0%
#  Cost: -5.022611 Accuracy: 38.0%
#  Cost: -5.078979 Accuracy: 38.0%
#  Cost: -5.135368 Accuracy: 38.0%
#  Cost: -5.191776 Accuracy: 38.0%
#  Cost: -5.248202 Accuracy: 38.0%
#  Cost: -5.304645 Accuracy: 38.0%
#  Cost: -5.361106 Accuracy: 38.0%
#  Cost: -5.417581 Accuracy: 38.0%
#  Cost: -5.474072 Accuracy: 38.0%
#  Cost: -5.530577 Accuracy: 38.0%
#  Cost: -5.587095 Accuracy: 38.0%
#  Cost: -5.643626 Accuracy: 38.0%
#  Cost: -5.700170 Accuracy: 38.0%
#  Cost: -5.756724 Accuracy: 38.0%
#  Cost: -5.813290 Accuracy: 38.0%
#  Cost: -5.869867 Accuracy: 38.0%
#  Cost: -5.926453 Accuracy: 38.0%
#  Cost: -5.983049 Accuracy: 38.0%
#  Cost: -6.039655 Accuracy: 38.0%
#  Cost: -6.096269 Accuracy: 38.0%
#  Cost: -6.152891 Accuracy: 38.0%
#  Cost: -6.209521 Accuracy: 38.0%
#  Cost: -6.266159 Accuracy: 38.0%
#  Cost: -6.322804 Accuracy: 38.0%
#  Cost: -6.379456 Accuracy: 38.0%
#  Cost: -6.436115 Accuracy: 38.0%
#  Cost: -6.492780 Accuracy: 38.0%
#  Cost: -6.549452 Accuracy: 38.0%
#  Cost: -6.606129 Accuracy: 38.0%
#  Cost: -6.662813 Accuracy: 38.0%
#  Cost: -6.719501 Accuracy: 38.0%
#  Cost: -6.776195 Accuracy: 38.0%
#  Cost: -6.832894 Accuracy: 38.0%
#  Cost: -6.889598 Accuracy: 38.0%
#  Cost: -6.946307 Accuracy: 38.0%
#  Cost: -7.003021 Accuracy: 38.0%
#  Cost: -7.059739 Accuracy: 38.0%
#  Cost: -7.116461 Accuracy: 38.0%
#  Cost: -7.173187 Accuracy: 38.0%
#  Cost: -7.229918 Accuracy: 38.0%
#  Cost: -7.286653 Accuracy: 38.0%
#  Cost: -7.343391 Accuracy: 38.0%
#  Cost: -7.400134 Accuracy: 38.0%
#  Cost: -7.456880 Accuracy: 38.0%
#  Cost: -7.513629 Accuracy: 38.0%
#  Cost: -7.570383 Accuracy: 38.0%
#  Cost: -7.627139 Accuracy: 38.0%
#  Cost: -7.683900 Accuracy: 38.0%
#  Cost: -7.740663 Accuracy: 38.0%
#  Cost: -7.797430 Accuracy: 38.0%
#  Cost: -7.854200 Accuracy: 38.0%
#  Cost: -7.910973 Accuracy: 38.0%
#  Cost: -7.967750 Accuracy: 38.0%
#  Cost: -8.024529 Accuracy: 38.0%
#  Cost: -8.081312 Accuracy: 38.0%
#  Cost: -8.138098 Accuracy: 38.0%
#  Cost: -8.194887 Accuracy: 38.0%
#  Cost: -8.251679 Accuracy: 38.0%
#  Cost: -8.308474 Accuracy: 38.0%
#  Cost: -8.365271 Accuracy: 38.0%
#  Cost: -8.422072 Accuracy: 38.0%
#  Cost: -8.478876 Accuracy: 38.0%
#  Cost: -8.535683 Accuracy: 38.0%
#  Cost: -8.592492 Accuracy: 38.0%
#  Cost: -8.649305 Accuracy: 38.0%
#  Cost: -8.706120 Accuracy: 38.0%
#  Cost: -8.762938 Accuracy: 38.0%
#  Cost: -8.819760 Accuracy: 38.0%
#  Cost: -8.876584 Accuracy: 38.0%
#  Cost: -8.933411 Accuracy: 38.0%
#  Cost: -8.990241 Accuracy: 38.0%
#  Cost: -9.047074 Accuracy: 38.0%
#  Cost: -9.103910 Accuracy: 38.0%
#  Cost: -9.160749 Accuracy: 38.0%
#  Cost: -9.217590 Accuracy: 38.0%
#  Cost: -9.274435 Accuracy: 38.0%
#  Cost: -9.331283 Accuracy: 38.0%
#  Cost: -9.388133 Accuracy: 38.0%
#  Cost: -9.444987 Accuracy: 38.0%
#  Cost: -9.501844 Accuracy: 38.0%
#  Cost: -9.558703 Accuracy: 38.0%
#  Cost: -9.615566 Accuracy: 38.0%
#  Cost: -9.672432 Accuracy: 38.0%
#  Cost: -9.729301 Accuracy: 38.0%
#  Cost: -9.786173 Accuracy: 38.0%
#  Cost: -9.843048 Accuracy: 38.0%
#  Cost: -9.899926 Accuracy: 38.0%
#  Cost: -9.956807 Accuracy: 38.0%
#  Cost: -10.013692 Accuracy: 38.0%
#  Cost: -10.070579 Accuracy: 38.0%
#  Cost: -10.127470 Accuracy: 38.0%
#  Cost: -10.184364 Accuracy: 38.0%
#  Cost: -10.241261 Accuracy: 38.0%
#  Cost: -10.298162 Accuracy: 38.0%
#  Cost: -10.355066 Accuracy: 38.0%
#  Cost: -10.411973 Accuracy: 38.0%
#  Cost: -10.468883 Accuracy: 38.0%
#  Cost: -10.525797 Accuracy: 38.0%
#  Cost: -10.582714 Accuracy: 38.0%
#  Cost: -10.639635 Accuracy: 38.0%
#  Cost: -10.696558 Accuracy: 38.0%
#  Cost: -10.753486 Accuracy: 38.0%
#  Cost: -10.810417 Accuracy: 38.0%
#  Cost: -10.867351 Accuracy: 38.0%
#  Cost: -10.924288 Accuracy: 38.0%
#  Cost: -10.981230 Accuracy: 38.0%
#  Cost: -11.038174 Accuracy: 38.0%
#  Cost: -11.095123 Accuracy: 38.0%
#  Cost: -11.152075 Accuracy: 38.0%
#  Cost: -11.209030 Accuracy: 38.0%
#  Cost: -11.265989 Accuracy: 38.0%
#  Cost: -11.322952 Accuracy: 38.0%
#  Cost: -11.379918 Accuracy: 38.0%
#  Cost: -11.436888 Accuracy: 38.0%
#  Cost: -11.493862 Accuracy: 38.0%
#  Cost: -11.550839 Accuracy: 38.0%
#  Cost: -11.607820 Accuracy: 38.0%
#  Cost: -11.664805 Accuracy: 38.0%
#  Cost: -11.721794 Accuracy: 38.0%
#  Cost: -11.778786 Accuracy: 38.0%
#  Cost: -11.835783 Accuracy: 38.0%
#  Cost: -11.892783 Accuracy: 38.0%
#  Cost: -11.949787 Accuracy: 38.0%
#  Cost: -12.006794 Accuracy: 38.0%
#  Cost: -12.063806 Accuracy: 38.0%
#  Cost: -12.120821 Accuracy: 38.0%
#  Cost: -12.177841 Accuracy: 38.0%
#  Cost: -12.234864 Accuracy: 38.0%
#  Cost: -12.291892 Accuracy: 38.0%
#  Cost: -12.348923 Accuracy: 38.0%
#  Cost: -12.405958 Accuracy: 38.0%
#  Cost: -12.462997 Accuracy: 38.0%
#  Cost: -12.520041 Accuracy: 38.0%
#  Cost: -12.577088 Accuracy: 38.0%
#  Cost: -12.634139 Accuracy: 38.0%
#  Cost: -12.691194 Accuracy: 38.0%
#  Cost: -12.748254 Accuracy: 38.0%
#  Cost: -12.805317 Accuracy: 38.0%
#  Cost: -12.862385 Accuracy: 38.0%
#  Cost: -12.919457 Accuracy: 38.0%
#  Cost: -12.976532 Accuracy: 38.0%
#  Cost: -13.033612 Accuracy: 38.0%
#  Cost: -13.090696 Accuracy: 38.0%
#  Cost: -13.147785 Accuracy: 38.0%
#  Cost: -13.204877 Accuracy: 38.0%
#  Cost: -13.261974 Accuracy: 38.0%
#  Cost: -13.319074 Accuracy: 38.0%
#  Cost: -13.376179 Accuracy: 38.0%
#  Cost: -13.433288 Accuracy: 38.0%
#  Cost: -13.490402 Accuracy: 38.0%
#  Cost: -13.547519 Accuracy: 38.0%
#  Cost: -13.604641 Accuracy: 38.0%
#  Cost: -13.661767 Accuracy: 38.0%
#  Cost: -13.718898 Accuracy: 38.0%
#  Cost: -13.776032 Accuracy: 38.0%
#  Cost: -13.833171 Accuracy: 38.0%
#  Cost: -13.890314 Accuracy: 38.0%
#  Cost: -13.947462 Accuracy: 38.0%
#  Cost: -14.004613 Accuracy: 38.0%
#  Cost: -14.061769 Accuracy: 38.0%
#  Cost: -14.118930 Accuracy: 38.0%
#  Cost: -14.176094 Accuracy: 38.0%
#  Cost: -14.233263 Accuracy: 38.0%
#  Cost: -14.290436 Accuracy: 38.0%
#  Cost: -14.347614 Accuracy: 38.0%
#  Cost: -14.404796 Accuracy: 38.0%
#  Cost: -14.461982 Accuracy: 38.0%
#  Cost: -14.519173 Accuracy: 38.0%
#  Cost: -14.576368 Accuracy: 38.0%
#  Cost: -14.633567 Accuracy: 38.0%
#  Cost: -14.690771 Accuracy: 38.0%
#  Cost: -14.747979 Accuracy: 38.0%
#  Cost: -14.805191 Accuracy: 38.0%
#  Cost: -14.862408 Accuracy: 38.0%
#  Cost: -14.919629 Accuracy: 38.0%
#  Cost: -14.976854 Accuracy: 38.0%
#  Cost: -15.034084 Accuracy: 38.0%
#  Cost: -15.091318 Accuracy: 40.0%
#  Cost: -15.148556 Accuracy: 40.0%
#  Cost: -15.205799 Accuracy: 40.0%
#  Cost: -15.263046 Accuracy: 40.0%
#  Cost: -15.320298 Accuracy: 40.0%
#  Cost: -15.377554 Accuracy: 40.0%
#  Cost: -15.434814 Accuracy: 40.0%
#  Cost: -15.492079 Accuracy: 40.0%
#  Cost: -15.549348 Accuracy: 40.0%
#  Cost: -15.606621 Accuracy: 40.0%
#  Cost: -15.663899 Accuracy: 40.0%
#  Cost: -15.721181 Accuracy: 40.0%
#  Cost: -15.778467 Accuracy: 40.0%
#  Cost: -15.835758 Accuracy: 40.0%
#  Cost: -15.893053 Accuracy: 40.0%
#  Cost: -15.950352 Accuracy: 40.0%
#  Cost: -16.007656 Accuracy: 40.0%
#  Cost: -16.064964 Accuracy: 40.0%
#  Cost: -16.122276 Accuracy: 40.0%
#  Cost: -16.179593 Accuracy: 40.0%
#  Cost: -16.236914 Accuracy: 40.0%
#  Cost: -16.294240 Accuracy: 40.0%
#  Cost: -16.351569 Accuracy: 40.0%
#  Cost: -16.408903 Accuracy: 40.0%
#  Cost: -16.466241 Accuracy: 40.0%
#  Cost: -16.523584 Accuracy: 40.0%
#  Cost: -16.580931 Accuracy: 40.0%
#  Cost: -16.638282 Accuracy: 40.0%
#  Cost: -16.695637 Accuracy: 40.0%
#  Cost: -16.752997 Accuracy: 40.0%
#  Cost: -16.810361 Accuracy: 40.0%
#  Cost: -16.867729 Accuracy: 40.0%
#  Cost: -16.925101 Accuracy: 40.0%
#  Cost: -16.982478 Accuracy: 40.0%
#  Cost: -17.039858 Accuracy: 40.0%
#  Cost: -17.097243 Accuracy: 40.0%
#  Cost: -17.154633 Accuracy: 40.0%
#  Cost: -17.212026 Accuracy: 40.0%
#  Cost: -17.269424 Accuracy: 40.0%
#  Cost: -17.326825 Accuracy: 40.0%
#  Cost: -17.384231 Accuracy: 40.0%
#  Cost: -17.441641 Accuracy: 40.0%
#  Cost: -17.499056 Accuracy: 40.0%
#  Cost: -17.556474 Accuracy: 40.0%
# /home/garycc227/.venv/lib/python3.6/site-packages/ipykernel_launcher.py:66: RuntimeWarning: divide by zero encountered in log
#  Cost: -17.613897 Accuracy: 40.0%
#  Cost: -17.671323 Accuracy: 40.0%
#  Cost: -17.728754 Accuracy: 40.0%
#  Cost: -17.786189 Accuracy: 40.0%
#  Cost: -17.843628 Accuracy: 40.0%
#  Cost: -17.901071 Accuracy: 40.0%
#  Cost: -17.958518 Accuracy: 40.0%
#  Cost: -18.015969 Accuracy: 40.0%
#  Cost: -18.073424 Accuracy: 40.0%
#  Cost: -18.130883 Accuracy: 40.0%
#  Cost: -18.188346 Accuracy: 40.0%
#  Cost: -18.245813 Accuracy: 40.0%
#  Cost: -18.303285 Accuracy: 40.0%
#  Cost: -18.360760 Accuracy: 40.0%
#  Cost: -18.418239 Accuracy: 40.0%
#  Cost: -18.475722 Accuracy: 40.0%
#  Cost: -18.533209 Accuracy: 40.0%
#  Cost: -18.590700 Accuracy: 40.0%
#  Cost: -18.648194 Accuracy: 40.0%
#  Cost: -18.705693 Accuracy: 40.0%
#  Cost: -18.763196 Accuracy: 40.0%
#  Cost: -18.820702 Accuracy: 40.0%
#  Cost: -18.878213 Accuracy: 40.0%
#  Cost: -18.935727 Accuracy: 40.0%
#  Cost: -18.993245 Accuracy: 40.0%
#  Cost: -19.050766 Accuracy: 40.0%
#  Cost: -19.108292 Accuracy: 40.0%
#  Cost: -19.165821 Accuracy: 40.0%
#  Cost: -19.223354 Accuracy: 40.0%
#  Cost: -19.280891 Accuracy: 40.0%
#  Cost: -19.338432 Accuracy: 40.0%
#  Cost: -19.395976 Accuracy: 40.0%
#  Cost: -19.453524 Accuracy: 40.0%
#  Cost: -19.511076 Accuracy: 40.0%
#  Cost: -19.568631 Accuracy: 40.0%
#  Cost: -19.626190 Accuracy: 40.0%
#  Cost: -19.683753 Accuracy: 40.0%
#  Cost: -19.741319 Accuracy: 40.0%
#  Cost: -19.798889 Accuracy: 40.0%
#  Cost: -19.856462 Accuracy: 40.0%
#  Cost: -19.914040 Accuracy: 40.0%
#  Cost: -19.971620 Accuracy: 40.0%
#  Cost: -20.029204 Accuracy: 40.0%
#  Cost: -20.086792 Accuracy: 40.0%
#  Cost: -20.144383 Accuracy: 40.0%
#  Cost: -20.201978 Accuracy: 40.0%
#  Cost: -20.259576 Accuracy: 40.0%
#  Cost: -20.317177 Accuracy: 40.0%
#  Cost: -20.374782 Accuracy: 40.0%
#  Cost: -20.432391 Accuracy: 40.0%
#  Cost: -20.490003 Accuracy: 40.0%
#  Cost: -20.547618 Accuracy: 40.0%
#  Cost: -20.605236 Accuracy: 40.0%
#  Cost: -20.662858 Accuracy: 40.0%
#  Cost: -20.720483 Accuracy: 40.0%
#  Cost: -20.778112 Accuracy: 40.0%
#  Cost: -20.835744 Accuracy: 40.0%
#  Cost: -20.893379 Accuracy: 40.0%
#  Cost: -20.951017 Accuracy: 40.0%
#  Cost: -21.008659 Accuracy: 40.0%
#  Cost: -21.066304 Accuracy: 40.0%
#  Cost: -21.123951 Accuracy: 40.0%
#  Cost: -21.181603 Accuracy: 40.0%
#  Cost: -21.239257 Accuracy: 40.0%
#  Cost: -21.296915 Accuracy: 40.0%
#  Cost: -21.354575 Accuracy: 40.0%
#  Cost: -21.412239 Accuracy: 40.0%
#  Cost: -21.469906 Accuracy: 40.0%
#  Cost: -21.527575 Accuracy: 40.0%
#  Cost: -21.585248 Accuracy: 40.0%
#  Cost: -21.642924 Accuracy: 40.0%
#  Cost: -21.700603 Accuracy: 40.0%
#  Cost: -21.758285 Accuracy: 40.0%
#  Cost: -21.815970 Accuracy: 40.0%
#  Cost: -21.873658 Accuracy: 40.0%
#  Cost: -21.931349 Accuracy: 40.0%
#  Cost: -21.989042 Accuracy: 40.0%
#  Cost: -22.046739 Accuracy: 40.0%
#  Cost: -22.104439 Accuracy: 40.0%
#  Cost: -22.162141 Accuracy: 40.0%
#  Cost: -22.219845 Accuracy: 40.0%
